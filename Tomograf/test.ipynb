# %%
from init import *
# %matplotlib inline
# Out:
# Wybrano plik:  C:/Users/Rufus/Desktop/IwM-master/IwM-master/Tomograf/Kwadraty2.jpg

# %%
display_sliders()
# Out:
# Ustaw parametry sinogramu
# IntSlider(value=180, max=270, min=90, step=10)
# 'Ustaw wartość L'
# FloatSlider(value=0.5, max=4.0, step=0.01)
# 'Ustaw wartość alpha'
# IntSlider(value=200, max=400, min=10, step=10)
# 'Ustaw ilość detektorów'
# Checkbox(value=False, description='Czy zastosowac filtr', indent=False)

# %%
gif = sinograms()
# Out:
# time:  76.9206623

# %%
@interact(i=(0,len(gif)-1))    
def show_image_slider(i):
    plt.clf()
    plt.imshow(gif[i],cmap='gray')
# Out:
# interactive(children=(IntSlider(value=4, description='i', max=9), Output()), _dom_classes=('widget-interact',)…

# %%
display_texts()

# %%
save_dicom_data()

# %%
load_dicom_data()
