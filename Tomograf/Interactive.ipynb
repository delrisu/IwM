# %%
from init import *
# %matplotlib inline

# %%
start()
# Out:
# Wybrano plik:  C:/IwM/Tomograf/Shepp_logan.jpg

# %%
display_sliders()
# Out:
# Ustaw parametry sinogramu
# IntSlider(value=180, max=270, min=45, step=45)
# 'Ustaw wartość L'
# FloatSlider(value=2.0, max=4.0)
# 'Ustaw wartość alpha'
# IntSlider(value=180, max=720, min=90, step=90)
# 'Ustaw ilość detektorów'
# Checkbox(value=False, description='Czy zastosowac filtr', indent=False)

# %%
gif = sinograms()

# %%
@interact(i=(0,len(gif)-1))    
def show_image_slider(i):
    plt.clf()
    plt.imshow(gif[i],cmap='gray')
    print("RMSE: ", rmse(gif[i]))
# Out:
# interactive(children=(IntSlider(value=18, description='i', max=37), Output()), _dom_classes=('widget-interact'…

# %%
print("RMSE od iteracji")
rmseTab = []
for g in gif:
    rmseTab.append(rmse(g))
plt.plot(rmseTab)
plt.xticks([])
# Out:
# RMSE od iteracji
# ([], <a list of 0 Text xticklabel objects>)

# %%
display_texts()
# Out:
# Wypełnij informacje do DICOM'a
# Text(value='', placeholder='Patient Name')
# Text(value='', placeholder="Patient's Sex")
# Text(value='', placeholder="Patient's Weight")
# Text(value='', placeholder="Patient's Birthdate")
# Text(value='', placeholder="Patient's ID")
# Text(value='', placeholder='Image comment')
# Text(value='', placeholder='Study date')
# Text(value='', placeholder='Filename')

# %%
save_dicom_data(gif[-1])
# Out:
# File saved.

# %%
load_dicom_data()
# Out:
# Data urodzenia pacjenta:  1654-09-09
# Imie pacjenta:  Piotr Wietczak
# Płeć pacjenta:  Female
# Waga pacjenta:  666.0
# Id pacjenta:  69420
# Komentarze do zdjęcia:  Lolwut
# Data badań:  2020-04-02
