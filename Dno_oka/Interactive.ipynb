# %%
from functions import *

# %%
start()
# Out:
# Obliczanie maski za pomocą prostego algorytmu...
# Obliczanie maski za pomocą sieci neuronowych...
# ...
# 100/100 [==============================] - 2s 15ms/sample
# Nakładanie maski eksperckiej na obraz...
# Nakładanie maski prostego algorytmu na obraz...
# Nakładanie maski sieci neuronowej na obraz...
# Obliczanie statystyk prostego algorytmu...
#
# Prosty algorytm Bez stosowania proporcji
# Trafność: 94.30326159492827%
# Czułość: 72.14481987268886%
# Swoistość: 96.11321210125206%
# Prosty algorytm
# Trafność: 77.14098081257352%
# Czułość: 96.94266344641287%
# Swoistość: 66.88580381039677%
# Obliczanie statystyk sieci neuronowej...
#
# Sieć neuronowa Bez stosowania proporcji
# Trafność: 97.17561311311312%
# Czułość: 92.56707308653567%
# Swoistość: 97.55204885074649%
# Sieć neuronowa
# Trafność: 86.14545824057312%
# Czułość: 99.34838417617766%
# Swoistość: 76.49865708089736%
