# %%
from functions import *

# %%
start()
# Out:
# Obliczanie maski za pomocą prostego algorytmu...
# Obliczanie maski za pomocą sieci neuronowych...
# ...
# 100/100 [==============================] - 1s 14ms/sample
# Nakładanie maski eksperckiej na obraz...
# Nakładanie maski prostego algorytmu na obraz...
# Nakładanie maski sieci neuronowej na obraz...
# Obliczanie statystyk prostego algorytmu...
# Prosty algorytm Bez filtrowania
# Trafność: 0.841754427390791%
# Czułość: 0.34857521537442016%
# Swoistość: 0.8795967659920675%
# Prosty algorytm
# Trafność: 0.43134489599937903%
# Czułość: 0.8745866364302061%
# Swoistość: 0.3592025714546857%
# Obliczanie statystyk sieci neuronowej...
# Sieć neuronowa Bez filtrowania
# Trafność: 0.9731050767414404%
# Czułość: 0.802650762094102%
# Swoistość: 0.9861842774331333%
# Sieć neuronowa
# Trafność: 0.9016165033464069%
# Czułość: 0.9814832430758926%
# Swoistość: 0.8456120239227715%
